# %% [markdown]
# # Notebook 7 - Result Exploration

# %%
import pandas as pd

# %%
# Load results.csv, saved in function notebook
df = pd.read_csv('s3://labs20-arms-bucket/data/results.csv').drop(columns=['Unnamed: 0'])

# %%
df.sort_values(by='pdist_score', ascending=False).head(100)
# Out:
#      CONSIGNOR_INN    clust0    clust1    clust6  pdist_score
# 2322    7706216371  0.742857  0.142857  0.102857     0.978465
# 2854    7814121367  0.707317  0.121951  0.121951     0.976295
# 1664    6161053692  0.715074  0.148897  0.091912     0.968969
# 1988    6659007785  0.700000  0.150000  0.125000     0.965847
# 1211    5042145938  0.714286  0.166667  0.119048     0.963331
# 1818    6168094673  0.722772  0.118812  0.079208     0.962778
# 1552    6123015760  0.725490  0.156863  0.078431     0.957165
# 723     3442093695  0.725490  0.156863  0.078431     0.957165
# 702   332701210896  0.706897  0.172414  0.120690     0.955529
# 300     2311196470  0.741379  0.086207  0.124138     0.954208
# 2711    7736207543  0.685185  0.148148  0.129630     0.953639
# 2119    7302040482  0.770115  0.098659  0.112069     0.949568
# 1640    6154141429  0.686275  0.156863  0.137255     0.948798
# 2180    7536146773  0.684685  0.162162  0.103604     0.948108
# ...
